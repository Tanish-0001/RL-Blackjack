# %%
import random
import torch
import torch.nn as nn
from copy import deepcopy
from collections import deque
from blackjack import Game
from utils import get_game_state, get_game_state_sparse

# %%
class Player(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Player, self).__init__()

        self.stack_1 = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU()
        )

        self.stack_2 = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.ReLU()
        )

        self.stack_3 = nn.Linear(hidden_size // 2, 2)

    def forward(self, x):
        x = self.stack_1(x)
        x = self.stack_2(x)
        x = self.stack_3(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
learning_rate = 5e-4
model = Player(input_size=6, hidden_size=256).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
target_network = deepcopy(model)  # target network for stability during learning
memory = deque(maxlen=25_000)  # memory buffer for experience replay
batch_size = 128
gamma = 0.99  # bellman equation constant
epsilon = 0.8  # base exploration chance

# %%
def choose_action(e, state) -> int:
    """
    Choose an action according to the epsilon-greedy policy. 0 for hit, 1 for stay
    ---------------------------
    Parameters:
        e (float): the exploration chance
        state (torch.tensor): the current state of the game
    """
    if random.random() < e:
        return random.choice([0, 1])

    state = state.to(device)
    output = model(state)
    return torch.argmax(output).item()


def train():
    if len(memory) < batch_size:
        return

    batch = random.sample(memory, batch_size)
    states, actions, rewards, dones, next_states = zip(*batch)

    states = torch.stack(states).to(device)
    actions = torch.tensor(actions, dtype=torch.int64, device=device).reshape(batch_size)
    rewards = torch.tensor(rewards, dtype=torch.float32).reshape(batch_size).to(device)  # Convert rewards to a tensor
    dones = torch.tensor(dones, dtype=torch.float32).reshape(batch_size).to(device)  # Convert dones to a tensor

    q_values = model(states)
    predicted_q_values = q_values.gather(1, actions.unsqueeze(1)).squeeze(1)  # get the q values for the corresponding actions taken

    next_q_values = torch.zeros(batch_size, device=device)

    non_terminal_mask = (dones == 0)  # Mask for non-terminal states
    non_terminal_next_states = [s for s in next_states if s is not None]

    if non_terminal_next_states:
        non_terminal_next_states = torch.stack(non_terminal_next_states).to(device)
        next_q_values[non_terminal_mask] = torch.max(target_network(non_terminal_next_states), dim=1).values

    target_q_values = rewards + gamma * next_q_values * (1 - dones)  # target q values according to bellman equation

    loss = criterion(target_q_values, predicted_q_values)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

win = 0
recent_wins = 0
for episode in range(1, 500_001):
    if episode % 100 == 0:
        epsilon = max(epsilon * 0.99, 0.05)  # decay the exploration chance

    game = Game(five_card_charlie=True)  # each episode starts a new game; the deck is NOT re-used.
    while not game.is_over:
        state = get_game_state(game)
        action = choose_action(epsilon, state)

        if action == 0:
            game.take_action("H")
        else:
            game.take_action("S")

        reward = game.score
        done = int(game.is_over)

        if done:
            next_state = None
        else:
            next_state = get_game_state(game)

        memory.append((state, action, reward, done, next_state))

    if game.score == 1:
        win += 1
        recent_wins += 1

    train()

    if episode % 1000 == 0:
        target_network.load_state_dict(model.state_dict())
        print(f"Episode: {episode}, Lifetime winrate: {win / episode:.4f}, Recent Winrate: {recent_wins / 1000:.4f}")
        recent_wins = 0

    if episode % 50_000 == 0:
        learning_rate /= 2
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# Episode: 1000, Lifetime winrate: 0.3040, Recent Winrate: 0.3040
# Episode: 2000, Lifetime winrate: 0.3130, Recent Winrate: 0.3220
# Episode: 3000, Lifetime winrate: 0.3343, Recent Winrate: 0.3770
# Episode: 4000, Lifetime winrate: 0.3350, Recent Winrate: 0.3370
# Episode: 5000, Lifetime winrate: 0.3412, Recent Winrate: 0.3660
# Episode: 6000, Lifetime winrate: 0.3387, Recent Winrate: 0.3260
# Episode: 7000, Lifetime winrate: 0.3450, Recent Winrate: 0.3830
# Episode: 8000, Lifetime winrate: 0.3459, Recent Winrate: 0.3520
# Episode: 9000, Lifetime winrate: 0.3457, Recent Winrate: 0.3440
# Episode: 10000, Lifetime winrate: 0.3467, Recent Winrate: 0.3560
# Episode: 11000, Lifetime winrate: 0.3488, Recent Winrate: 0.3700
# Episode: 12000, Lifetime winrate: 0.3494, Recent Winrate: 0.3560
# Episode: 13000, Lifetime winrate: 0.3518, Recent Winrate: 0.3810
# Episode: 14000, Lifetime winrate: 0.3510, Recent Winrate: 0.3400
# Episode: 15000, Lifetime winrate: 0.3525, Recent Winrate: 0.3730
# Episode: 16000, Lifetime winrate: 0.3543, Recent Winrate: 0.3810
# Episode: 17000, Lifetime winrate: 0.3561, Recent Winrate: 0.3850
# Episode: 18000, Lifetime winrate: 0.3580, Recent Winrate: 0.3910
# Episode: 19000, Lifetime winrate: 0.3592, Recent Winrate: 0.3810
# Episode: 20000, Lifetime winrate: 0.3597, Recent Winrate: 0.3680
# Episode: 21000, Lifetime winrate: 0.3609, Recent Winrate: 0.3860
# Episode: 22000, Lifetime winrate: 0.3614, Recent Winrate: 0.3720
# Episode: 23000, Lifetime winrate: 0.3632, Recent Winrate: 0.4020
# Episode: 24000, Lifetime winrate: 0.3644, Recent Winrate: 0.3920
# Episode: 25000, Lifetime winrate: 0.3645, Recent Winrate: 0.3670
# Episode: 26000, Lifetime winrate: 0.3652, Recent Winrate: 0.3820
# Episode: 27000, Lifetime winrate: 0.3667, Recent Winrate: 0.4080
# Episode: 28000, Lifetime winrate: 0.3682, Recent Winrate: 0.4070
# Episode: 29000, Lifetime winrate: 0.3699, Recent Winrate: 0.4170
# Episode: 30000, Lifetime winrate: 0.3707, Recent Winrate: 0.3960
# Episode: 31000, Lifetime winrate: 0.3721, Recent Winrate: 0.4130
# Episode: 32000, Lifetime winrate: 0.3727, Recent Winrate: 0.3920
# Episode: 33000, Lifetime winrate: 0.3737, Recent Winrate: 0.4050
# Episode: 34000, Lifetime winrate: 0.3741, Recent Winrate: 0.3860
# Episode: 35000, Lifetime winrate: 0.3746, Recent Winrate: 0.3930
# Episode: 36000, Lifetime winrate: 0.3750, Recent Winrate: 0.3890
# Episode: 37000, Lifetime winrate: 0.3755, Recent Winrate: 0.3950
# Episode: 38000, Lifetime winrate: 0.3756, Recent Winrate: 0.3760
# Episode: 39000, Lifetime winrate: 0.3763, Recent Winrate: 0.4030
# Episode: 40000, Lifetime winrate: 0.3770, Recent Winrate: 0.4050
# Episode: 41000, Lifetime winrate: 0.3774, Recent Winrate: 0.3960
# Episode: 42000, Lifetime winrate: 0.3773, Recent Winrate: 0.3710
# Episode: 43000, Lifetime winrate: 0.3775, Recent Winrate: 0.3880
# Episode: 44000, Lifetime winrate: 0.3778, Recent Winrate: 0.3900
# Episode: 45000, Lifetime winrate: 0.3786, Recent Winrate: 0.4150
# Episode: 46000, Lifetime winrate: 0.3792, Recent Winrate: 0.4060
# Episode: 47000, Lifetime winrate: 0.3797, Recent Winrate: 0.4030
# Episode: 48000, Lifetime winrate: 0.3800, Recent Winrate: 0.3910
# Episode: 49000, Lifetime winrate: 0.3806, Recent Winrate: 0.4100
# Episode: 50000, Lifetime winrate: 0.3806, Recent Winrate: 0.3790
# Episode: 51000, Lifetime winrate: 0.3806, Recent Winrate: 0.3840
# Episode: 52000, Lifetime winrate: 0.3813, Recent Winrate: 0.4150
# Episode: 53000, Lifetime winrate: 0.3821, Recent Winrate: 0.4240
# Episode: 54000, Lifetime winrate: 0.3818, Recent Winrate: 0.3670
# Episode: 55000, Lifetime winrate: 0.3823, Recent Winrate: 0.4090
# Episode: 56000, Lifetime winrate: 0.3825, Recent Winrate: 0.3930
# Episode: 57000, Lifetime winrate: 0.3833, Recent Winrate: 0.4280
# Episode: 58000, Lifetime winrate: 0.3834, Recent Winrate: 0.3900
# Episode: 59000, Lifetime winrate: 0.3837, Recent Winrate: 0.3980
# Episode: 60000, Lifetime winrate: 0.3841, Recent Winrate: 0.4080
# Episode: 61000, Lifetime winrate: 0.3844, Recent Winrate: 0.4030
# Episode: 62000, Lifetime winrate: 0.3843, Recent Winrate: 0.3810
# Episode: 63000, Lifetime winrate: 0.3848, Recent Winrate: 0.4160
# Episode: 64000, Lifetime winrate: 0.3847, Recent Winrate: 0.3790
# Episode: 65000, Lifetime winrate: 0.3850, Recent Winrate: 0.4010
# Episode: 66000, Lifetime winrate: 0.3854, Recent Winrate: 0.4100
# Episode: 67000, Lifetime winrate: 0.3856, Recent Winrate: 0.4020
# Episode: 68000, Lifetime winrate: 0.3859, Recent Winrate: 0.4080
# Episode: 69000, Lifetime winrate: 0.3857, Recent Winrate: 0.3680
# Episode: 70000, Lifetime winrate: 0.3860, Recent Winrate: 0.4070
# Episode: 71000, Lifetime winrate: 0.3862, Recent Winrate: 0.4000
# Episode: 72000, Lifetime winrate: 0.3859, Recent Winrate: 0.3630
# Episode: 73000, Lifetime winrate: 0.3860, Recent Winrate: 0.3990
# Episode: 74000, Lifetime winrate: 0.3860, Recent Winrate: 0.3860
# Episode: 75000, Lifetime winrate: 0.3863, Recent Winrate: 0.4080
# Episode: 76000, Lifetime winrate: 0.3864, Recent Winrate: 0.3940
# Episode: 77000, Lifetime winrate: 0.3866, Recent Winrate: 0.3960
# Episode: 78000, Lifetime winrate: 0.3871, Recent Winrate: 0.4310
# Episode: 79000, Lifetime winrate: 0.3871, Recent Winrate: 0.3830
# Episode: 80000, Lifetime winrate: 0.3875, Recent Winrate: 0.4240
# Episode: 81000, Lifetime winrate: 0.3875, Recent Winrate: 0.3830
# Episode: 82000, Lifetime winrate: 0.3880, Recent Winrate: 0.4260
# Episode: 83000, Lifetime winrate: 0.3881, Recent Winrate: 0.4040
# Episode: 84000, Lifetime winrate: 0.3886, Recent Winrate: 0.4300
# Episode: 85000, Lifetime winrate: 0.3886, Recent Winrate: 0.3840
# Episode: 86000, Lifetime winrate: 0.3886, Recent Winrate: 0.3910
# Episode: 87000, Lifetime winrate: 0.3890, Recent Winrate: 0.4230
# Episode: 88000, Lifetime winrate: 0.3893, Recent Winrate: 0.4150
# Episode: 89000, Lifetime winrate: 0.3897, Recent Winrate: 0.4220
# Episode: 90000, Lifetime winrate: 0.3901, Recent Winrate: 0.4300
# Episode: 91000, Lifetime winrate: 0.3905, Recent Winrate: 0.4210
# Episode: 92000, Lifetime winrate: 0.3905, Recent Winrate: 0.3920
# Episode: 93000, Lifetime winrate: 0.3910, Recent Winrate: 0.4410
# Episode: 94000, Lifetime winrate: 0.3911, Recent Winrate: 0.3940
# Episode: 95000, Lifetime winrate: 0.3913, Recent Winrate: 0.4140
# Episode: 96000, Lifetime winrate: 0.3913, Recent Winrate: 0.3910
# Episode: 97000, Lifetime winrate: 0.3915, Recent Winrate: 0.4070
# Episode: 98000, Lifetime winrate: 0.3918, Recent Winrate: 0.4230
# Episode: 99000, Lifetime winrate: 0.3920, Recent Winrate: 0.4110
# Episode: 100000, Lifetime winrate: 0.3918, Recent Winrate: 0.3760
# Episode: 101000, Lifetime winrate: 0.3920, Recent Winrate: 0.4090
# Episode: 102000, Lifetime winrate: 0.3922, Recent Winrate: 0.4120
# Episode: 103000, Lifetime winrate: 0.3922, Recent Winrate: 0.3940
# Episode: 104000, Lifetime winrate: 0.3927, Recent Winrate: 0.4440
# Episode: 105000, Lifetime winrate: 0.3928, Recent Winrate: 0.4090
# Episode: 106000, Lifetime winrate: 0.3929, Recent Winrate: 0.4010
# Episode: 107000, Lifetime winrate: 0.3930, Recent Winrate: 0.3970
# Episode: 108000, Lifetime winrate: 0.3931, Recent Winrate: 0.4080
# Episode: 109000, Lifetime winrate: 0.3932, Recent Winrate: 0.4000
# Episode: 110000, Lifetime winrate: 0.3933, Recent Winrate: 0.4090
# Episode: 111000, Lifetime winrate: 0.3934, Recent Winrate: 0.4040
# Episode: 112000, Lifetime winrate: 0.3935, Recent Winrate: 0.4050
# Episode: 113000, Lifetime winrate: 0.3936, Recent Winrate: 0.4080
# Episode: 114000, Lifetime winrate: 0.3937, Recent Winrate: 0.3960
# Episode: 115000, Lifetime winrate: 0.3939, Recent Winrate: 0.4210
# Episode: 116000, Lifetime winrate: 0.3941, Recent Winrate: 0.4120
# Episode: 117000, Lifetime winrate: 0.3943, Recent Winrate: 0.4200
# Episode: 118000, Lifetime winrate: 0.3942, Recent Winrate: 0.3910
# Episode: 119000, Lifetime winrate: 0.3946, Recent Winrate: 0.4380
# Episode: 120000, Lifetime winrate: 0.3948, Recent Winrate: 0.4180
# Episode: 121000, Lifetime winrate: 0.3949, Recent Winrate: 0.4100
# Episode: 122000, Lifetime winrate: 0.3951, Recent Winrate: 0.4200
# Episode: 123000, Lifetime winrate: 0.3951, Recent Winrate: 0.3860
# Episode: 124000, Lifetime winrate: 0.3948, Recent Winrate: 0.3670
# Episode: 125000, Lifetime winrate: 0.3950, Recent Winrate: 0.4150
# Episode: 126000, Lifetime winrate: 0.3953, Recent Winrate: 0.4270
# Episode: 127000, Lifetime winrate: 0.3956, Recent Winrate: 0.4340
# Episode: 128000, Lifetime winrate: 0.3956, Recent Winrate: 0.4040
# Episode: 129000, Lifetime winrate: 0.3958, Recent Winrate: 0.4190
# Episode: 130000, Lifetime winrate: 0.3959, Recent Winrate: 0.4120
# Episode: 131000, Lifetime winrate: 0.3961, Recent Winrate: 0.4140
# Episode: 132000, Lifetime winrate: 0.3963, Recent Winrate: 0.4320
# Episode: 133000, Lifetime winrate: 0.3964, Recent Winrate: 0.4050
# Episode: 134000, Lifetime winrate: 0.3963, Recent Winrate: 0.3840
# Episode: 135000, Lifetime winrate: 0.3965, Recent Winrate: 0.4160
# Episode: 136000, Lifetime winrate: 0.3967, Recent Winrate: 0.4260
# Episode: 137000, Lifetime winrate: 0.3969, Recent Winrate: 0.4260
# Episode: 138000, Lifetime winrate: 0.3969, Recent Winrate: 0.3920
# Episode: 139000, Lifetime winrate: 0.3969, Recent Winrate: 0.4050
# Episode: 140000, Lifetime winrate: 0.3972, Recent Winrate: 0.4300
# Episode: 141000, Lifetime winrate: 0.3972, Recent Winrate: 0.4040
# Episode: 142000, Lifetime winrate: 0.3973, Recent Winrate: 0.4050
# Episode: 143000, Lifetime winrate: 0.3972, Recent Winrate: 0.3950
# Episode: 144000, Lifetime winrate: 0.3972, Recent Winrate: 0.3890
# Episode: 145000, Lifetime winrate: 0.3973, Recent Winrate: 0.4160
# Episode: 146000, Lifetime winrate: 0.3975, Recent Winrate: 0.4180
# Episode: 147000, Lifetime winrate: 0.3974, Recent Winrate: 0.3950
# Episode: 148000, Lifetime winrate: 0.3977, Recent Winrate: 0.4360
# Episode: 149000, Lifetime winrate: 0.3978, Recent Winrate: 0.4070
# Episode: 150000, Lifetime winrate: 0.3978, Recent Winrate: 0.4040
# Episode: 151000, Lifetime winrate: 0.3979, Recent Winrate: 0.4080
# Episode: 152000, Lifetime winrate: 0.3979, Recent Winrate: 0.3980
# Episode: 153000, Lifetime winrate: 0.3979, Recent Winrate: 0.4050
# Episode: 154000, Lifetime winrate: 0.3980, Recent Winrate: 0.4040
# Episode: 155000, Lifetime winrate: 0.3980, Recent Winrate: 0.4070
# Episode: 156000, Lifetime winrate: 0.3981, Recent Winrate: 0.4190
# Episode: 157000, Lifetime winrate: 0.3982, Recent Winrate: 0.4100
# Episode: 158000, Lifetime winrate: 0.3983, Recent Winrate: 0.4060
# Episode: 159000, Lifetime winrate: 0.3984, Recent Winrate: 0.4240
# Episode: 160000, Lifetime winrate: 0.3984, Recent Winrate: 0.3920
# Episode: 161000, Lifetime winrate: 0.3985, Recent Winrate: 0.4140
# Episode: 162000, Lifetime winrate: 0.3985, Recent Winrate: 0.3960
# Episode: 163000, Lifetime winrate: 0.3986, Recent Winrate: 0.4240
# Episode: 164000, Lifetime winrate: 0.3986, Recent Winrate: 0.4000
# Episode: 165000, Lifetime winrate: 0.3987, Recent Winrate: 0.4030
# Episode: 166000, Lifetime winrate: 0.3988, Recent Winrate: 0.4230
# Episode: 167000, Lifetime winrate: 0.3987, Recent Winrate: 0.3750
# Episode: 168000, Lifetime winrate: 0.3988, Recent Winrate: 0.4280
# Episode: 169000, Lifetime winrate: 0.3989, Recent Winrate: 0.4020
# Episode: 170000, Lifetime winrate: 0.3990, Recent Winrate: 0.4210
# Episode: 171000, Lifetime winrate: 0.3990, Recent Winrate: 0.4060
# Episode: 172000, Lifetime winrate: 0.3991, Recent Winrate: 0.4140
# Episode: 173000, Lifetime winrate: 0.3993, Recent Winrate: 0.4340
# Episode: 174000, Lifetime winrate: 0.3993, Recent Winrate: 0.3930
# Episode: 175000, Lifetime winrate: 0.3994, Recent Winrate: 0.4250
# Episode: 176000, Lifetime winrate: 0.3996, Recent Winrate: 0.4350
# Episode: 177000, Lifetime winrate: 0.3996, Recent Winrate: 0.4020
# Episode: 178000, Lifetime winrate: 0.3997, Recent Winrate: 0.4030
# Episode: 179000, Lifetime winrate: 0.3996, Recent Winrate: 0.3950
# Episode: 180000, Lifetime winrate: 0.3996, Recent Winrate: 0.3890
# Episode: 181000, Lifetime winrate: 0.3996, Recent Winrate: 0.4050
# Episode: 182000, Lifetime winrate: 0.3996, Recent Winrate: 0.4030
# Episode: 183000, Lifetime winrate: 0.3998, Recent Winrate: 0.4360
# Episode: 184000, Lifetime winrate: 0.4000, Recent Winrate: 0.4370
# Episode: 185000, Lifetime winrate: 0.4000, Recent Winrate: 0.3930
# Episode: 186000, Lifetime winrate: 0.4000, Recent Winrate: 0.4040
# Episode: 187000, Lifetime winrate: 0.4001, Recent Winrate: 0.4170
# Episode: 188000, Lifetime winrate: 0.4001, Recent Winrate: 0.3900
# Episode: 189000, Lifetime winrate: 0.4001, Recent Winrate: 0.4160
# Episode: 190000, Lifetime winrate: 0.4002, Recent Winrate: 0.4110
# Episode: 191000, Lifetime winrate: 0.4001, Recent Winrate: 0.3870
# Episode: 192000, Lifetime winrate: 0.4000, Recent Winrate: 0.3790
# Episode: 193000, Lifetime winrate: 0.4001, Recent Winrate: 0.4090
# Episode: 194000, Lifetime winrate: 0.4001, Recent Winrate: 0.4000
# Episode: 195000, Lifetime winrate: 0.4002, Recent Winrate: 0.4320
# Episode: 196000, Lifetime winrate: 0.4002, Recent Winrate: 0.3890
# Episode: 197000, Lifetime winrate: 0.4001, Recent Winrate: 0.3900
# Episode: 198000, Lifetime winrate: 0.4002, Recent Winrate: 0.4140
# Episode: 199000, Lifetime winrate: 0.4003, Recent Winrate: 0.4220
# Episode: 200000, Lifetime winrate: 0.4003, Recent Winrate: 0.4020
# Episode: 201000, Lifetime winrate: 0.4005, Recent Winrate: 0.4440
# Episode: 202000, Lifetime winrate: 0.4007, Recent Winrate: 0.4340
# Episode: 203000, Lifetime winrate: 0.4007, Recent Winrate: 0.4070
# Episode: 204000, Lifetime winrate: 0.4008, Recent Winrate: 0.4190
# Episode: 205000, Lifetime winrate: 0.4009, Recent Winrate: 0.4120
# Episode: 206000, Lifetime winrate: 0.4010, Recent Winrate: 0.4340
# Episode: 207000, Lifetime winrate: 0.4010, Recent Winrate: 0.4010
# Episode: 208000, Lifetime winrate: 0.4012, Recent Winrate: 0.4320
# Episode: 209000, Lifetime winrate: 0.4011, Recent Winrate: 0.3850
# Episode: 210000, Lifetime winrate: 0.4012, Recent Winrate: 0.4290
# Episode: 211000, Lifetime winrate: 0.4012, Recent Winrate: 0.4030
# Episode: 212000, Lifetime winrate: 0.4014, Recent Winrate: 0.4330
# Episode: 213000, Lifetime winrate: 0.4015, Recent Winrate: 0.4190
# Episode: 214000, Lifetime winrate: 0.4016, Recent Winrate: 0.4220
# Episode: 215000, Lifetime winrate: 0.4015, Recent Winrate: 0.3940
# Episode: 216000, Lifetime winrate: 0.4016, Recent Winrate: 0.4200
# Episode: 217000, Lifetime winrate: 0.4017, Recent Winrate: 0.4290
# Episode: 218000, Lifetime winrate: 0.4017, Recent Winrate: 0.3980
# Episode: 219000, Lifetime winrate: 0.4017, Recent Winrate: 0.4070
# Episode: 220000, Lifetime winrate: 0.4018, Recent Winrate: 0.4210
# Episode: 221000, Lifetime winrate: 0.4019, Recent Winrate: 0.4240
# Episode: 222000, Lifetime winrate: 0.4020, Recent Winrate: 0.4080
# Episode: 223000, Lifetime winrate: 0.4020, Recent Winrate: 0.4130
# Episode: 224000, Lifetime winrate: 0.4022, Recent Winrate: 0.4330
# Episode: 225000, Lifetime winrate: 0.4023, Recent Winrate: 0.4260
# Episode: 226000, Lifetime winrate: 0.4022, Recent Winrate: 0.3970
# Episode: 227000, Lifetime winrate: 0.4023, Recent Winrate: 0.4120
# Episode: 228000, Lifetime winrate: 0.4025, Recent Winrate: 0.4440
# Episode: 229000, Lifetime winrate: 0.4026, Recent Winrate: 0.4230
# Episode: 230000, Lifetime winrate: 0.4026, Recent Winrate: 0.4150
# Episode: 231000, Lifetime winrate: 0.4027, Recent Winrate: 0.4350
# Episode: 232000, Lifetime winrate: 0.4027, Recent Winrate: 0.3880
# Episode: 233000, Lifetime winrate: 0.4027, Recent Winrate: 0.3980
# Episode: 234000, Lifetime winrate: 0.4027, Recent Winrate: 0.4170
# Episode: 235000, Lifetime winrate: 0.4028, Recent Winrate: 0.4230
# Episode: 236000, Lifetime winrate: 0.4028, Recent Winrate: 0.4090
# Episode: 237000, Lifetime winrate: 0.4029, Recent Winrate: 0.4130
# Episode: 238000, Lifetime winrate: 0.4030, Recent Winrate: 0.4320
# Episode: 239000, Lifetime winrate: 0.4031, Recent Winrate: 0.4240
# Episode: 240000, Lifetime winrate: 0.4030, Recent Winrate: 0.3920
# Episode: 241000, Lifetime winrate: 0.4031, Recent Winrate: 0.4060
# Episode: 242000, Lifetime winrate: 0.4031, Recent Winrate: 0.4120
# Episode: 243000, Lifetime winrate: 0.4029, Recent Winrate: 0.3640
# Episode: 244000, Lifetime winrate: 0.4029, Recent Winrate: 0.4010
# Episode: 245000, Lifetime winrate: 0.4029, Recent Winrate: 0.3980
# Episode: 246000, Lifetime winrate: 0.4029, Recent Winrate: 0.3990
# Episode: 247000, Lifetime winrate: 0.4030, Recent Winrate: 0.4350
# Episode: 248000, Lifetime winrate: 0.4031, Recent Winrate: 0.4220
# Episode: 249000, Lifetime winrate: 0.4031, Recent Winrate: 0.4040
# Episode: 250000, Lifetime winrate: 0.4031, Recent Winrate: 0.3960
# Episode: 251000, Lifetime winrate: 0.4032, Recent Winrate: 0.4280
# Episode: 252000, Lifetime winrate: 0.4034, Recent Winrate: 0.4520
# Episode: 253000, Lifetime winrate: 0.4033, Recent Winrate: 0.3940
# Episode: 254000, Lifetime winrate: 0.4034, Recent Winrate: 0.4100
# Episode: 255000, Lifetime winrate: 0.4034, Recent Winrate: 0.4200
# Episode: 256000, Lifetime winrate: 0.4035, Recent Winrate: 0.4140
# Episode: 257000, Lifetime winrate: 0.4035, Recent Winrate: 0.4100
# Episode: 258000, Lifetime winrate: 0.4035, Recent Winrate: 0.4000
# Episode: 259000, Lifetime winrate: 0.4035, Recent Winrate: 0.4030
# Episode: 260000, Lifetime winrate: 0.4034, Recent Winrate: 0.3930
# Episode: 261000, Lifetime winrate: 0.4034, Recent Winrate: 0.4060
# Episode: 262000, Lifetime winrate: 0.4035, Recent Winrate: 0.4140
# Episode: 263000, Lifetime winrate: 0.4036, Recent Winrate: 0.4310
# Episode: 264000, Lifetime winrate: 0.4036, Recent Winrate: 0.4160
# Episode: 265000, Lifetime winrate: 0.4037, Recent Winrate: 0.4200
# Episode: 266000, Lifetime winrate: 0.4038, Recent Winrate: 0.4370
# Episode: 267000, Lifetime winrate: 0.4038, Recent Winrate: 0.4010
# Episode: 268000, Lifetime winrate: 0.4039, Recent Winrate: 0.4200
# Episode: 269000, Lifetime winrate: 0.4039, Recent Winrate: 0.4070
# Episode: 270000, Lifetime winrate: 0.4039, Recent Winrate: 0.4150
# Episode: 271000, Lifetime winrate: 0.4041, Recent Winrate: 0.4420
# Episode: 272000, Lifetime winrate: 0.4041, Recent Winrate: 0.4120
# Episode: 273000, Lifetime winrate: 0.4042, Recent Winrate: 0.4350
# Episode: 274000, Lifetime winrate: 0.4042, Recent Winrate: 0.4030
# Episode: 275000, Lifetime winrate: 0.4042, Recent Winrate: 0.4110
# Episode: 276000, Lifetime winrate: 0.4043, Recent Winrate: 0.4160
# Episode: 277000, Lifetime winrate: 0.4043, Recent Winrate: 0.4090
# Episode: 278000, Lifetime winrate: 0.4043, Recent Winrate: 0.4010
# Episode: 279000, Lifetime winrate: 0.4044, Recent Winrate: 0.4430
# Episode: 280000, Lifetime winrate: 0.4044, Recent Winrate: 0.4140
# Episode: 281000, Lifetime winrate: 0.4045, Recent Winrate: 0.4240
# Episode: 282000, Lifetime winrate: 0.4045, Recent Winrate: 0.3940
# Episode: 283000, Lifetime winrate: 0.4045, Recent Winrate: 0.4240
# Episode: 284000, Lifetime winrate: 0.4045, Recent Winrate: 0.3890
# Episode: 285000, Lifetime winrate: 0.4045, Recent Winrate: 0.4000
# Episode: 286000, Lifetime winrate: 0.4044, Recent Winrate: 0.3840
# Episode: 287000, Lifetime winrate: 0.4044, Recent Winrate: 0.4090
# Episode: 288000, Lifetime winrate: 0.4044, Recent Winrate: 0.3990
# Episode: 289000, Lifetime winrate: 0.4044, Recent Winrate: 0.4160
# Episode: 290000, Lifetime winrate: 0.4045, Recent Winrate: 0.4140
# Episode: 291000, Lifetime winrate: 0.4044, Recent Winrate: 0.3890
# Episode: 292000, Lifetime winrate: 0.4045, Recent Winrate: 0.4140
# Episode: 293000, Lifetime winrate: 0.4045, Recent Winrate: 0.4220
# Episode: 294000, Lifetime winrate: 0.4045, Recent Winrate: 0.3870
# Episode: 295000, Lifetime winrate: 0.4045, Recent Winrate: 0.4160
# Episode: 296000, Lifetime winrate: 0.4045, Recent Winrate: 0.4100
# Episode: 297000, Lifetime winrate: 0.4045, Recent Winrate: 0.4070
# Episode: 298000, Lifetime winrate: 0.4045, Recent Winrate: 0.4050
# Episode: 299000, Lifetime winrate: 0.4045, Recent Winrate: 0.4000
# Episode: 300000, Lifetime winrate: 0.4046, Recent Winrate: 0.4200
# Episode: 301000, Lifetime winrate: 0.4046, Recent Winrate: 0.4120
# Episode: 302000, Lifetime winrate: 0.4046, Recent Winrate: 0.4160
# Episode: 303000, Lifetime winrate: 0.4046, Recent Winrate: 0.3940
# Episode: 304000, Lifetime winrate: 0.4046, Recent Winrate: 0.4060
# Episode: 305000, Lifetime winrate: 0.4046, Recent Winrate: 0.4230
# Episode: 306000, Lifetime winrate: 0.4047, Recent Winrate: 0.4270
# Episode: 307000, Lifetime winrate: 0.4047, Recent Winrate: 0.3870
# Episode: 308000, Lifetime winrate: 0.4046, Recent Winrate: 0.3980
# Episode: 309000, Lifetime winrate: 0.4046, Recent Winrate: 0.4050
# Episode: 310000, Lifetime winrate: 0.4046, Recent Winrate: 0.3880
# Episode: 311000, Lifetime winrate: 0.4047, Recent Winrate: 0.4440
# Episode: 312000, Lifetime winrate: 0.4047, Recent Winrate: 0.3940
# Episode: 313000, Lifetime winrate: 0.4047, Recent Winrate: 0.3960
# Episode: 314000, Lifetime winrate: 0.4047, Recent Winrate: 0.4120
# Episode: 315000, Lifetime winrate: 0.4048, Recent Winrate: 0.4290
# Episode: 316000, Lifetime winrate: 0.4048, Recent Winrate: 0.4190
# Episode: 317000, Lifetime winrate: 0.4048, Recent Winrate: 0.4040
# Episode: 318000, Lifetime winrate: 0.4048, Recent Winrate: 0.4100
# Episode: 319000, Lifetime winrate: 0.4048, Recent Winrate: 0.4070
# Episode: 320000, Lifetime winrate: 0.4048, Recent Winrate: 0.4060
# Episode: 321000, Lifetime winrate: 0.4050, Recent Winrate: 0.4450
# Episode: 322000, Lifetime winrate: 0.4050, Recent Winrate: 0.4070
# Episode: 323000, Lifetime winrate: 0.4050, Recent Winrate: 0.4100
# Episode: 324000, Lifetime winrate: 0.4050, Recent Winrate: 0.4040
# Episode: 325000, Lifetime winrate: 0.4051, Recent Winrate: 0.4500
# Episode: 326000, Lifetime winrate: 0.4052, Recent Winrate: 0.4200
# Episode: 327000, Lifetime winrate: 0.4052, Recent Winrate: 0.4220
# Episode: 328000, Lifetime winrate: 0.4052, Recent Winrate: 0.3950
# Episode: 329000, Lifetime winrate: 0.4052, Recent Winrate: 0.4250
# Episode: 330000, Lifetime winrate: 0.4053, Recent Winrate: 0.4330
# Episode: 331000, Lifetime winrate: 0.4054, Recent Winrate: 0.4190
# Episode: 332000, Lifetime winrate: 0.4054, Recent Winrate: 0.4200
# Episode: 333000, Lifetime winrate: 0.4054, Recent Winrate: 0.4110
# Episode: 334000, Lifetime winrate: 0.4055, Recent Winrate: 0.4360
# Episode: 335000, Lifetime winrate: 0.4056, Recent Winrate: 0.4350
# Episode: 336000, Lifetime winrate: 0.4056, Recent Winrate: 0.4190
# Episode: 337000, Lifetime winrate: 0.4057, Recent Winrate: 0.4410
# Episode: 338000, Lifetime winrate: 0.4058, Recent Winrate: 0.4200
# Episode: 339000, Lifetime winrate: 0.4058, Recent Winrate: 0.4150
# Episode: 340000, Lifetime winrate: 0.4058, Recent Winrate: 0.3990
# Episode: 341000, Lifetime winrate: 0.4059, Recent Winrate: 0.4270
# Episode: 342000, Lifetime winrate: 0.4059, Recent Winrate: 0.4260
# Episode: 343000, Lifetime winrate: 0.4060, Recent Winrate: 0.4460
# Episode: 344000, Lifetime winrate: 0.4060, Recent Winrate: 0.4120
# Episode: 345000, Lifetime winrate: 0.4061, Recent Winrate: 0.4250
# Episode: 346000, Lifetime winrate: 0.4062, Recent Winrate: 0.4320
# Episode: 347000, Lifetime winrate: 0.4062, Recent Winrate: 0.4290
# Episode: 348000, Lifetime winrate: 0.4063, Recent Winrate: 0.4100
# Episode: 349000, Lifetime winrate: 0.4063, Recent Winrate: 0.4060
# Episode: 350000, Lifetime winrate: 0.4063, Recent Winrate: 0.4070
# Episode: 351000, Lifetime winrate: 0.4063, Recent Winrate: 0.4050
# Episode: 352000, Lifetime winrate: 0.4063, Recent Winrate: 0.4290
# Episode: 353000, Lifetime winrate: 0.4063, Recent Winrate: 0.4100
# Episode: 354000, Lifetime winrate: 0.4063, Recent Winrate: 0.4050
# Episode: 355000, Lifetime winrate: 0.4063, Recent Winrate: 0.3920
# Episode: 356000, Lifetime winrate: 0.4062, Recent Winrate: 0.3850
# Episode: 357000, Lifetime winrate: 0.4062, Recent Winrate: 0.3970
# Episode: 358000, Lifetime winrate: 0.4062, Recent Winrate: 0.4160
# Episode: 359000, Lifetime winrate: 0.4063, Recent Winrate: 0.4390
# Episode: 360000, Lifetime winrate: 0.4063, Recent Winrate: 0.4020
# Episode: 361000, Lifetime winrate: 0.4063, Recent Winrate: 0.4020
# Episode: 362000, Lifetime winrate: 0.4064, Recent Winrate: 0.4270
# Episode: 363000, Lifetime winrate: 0.4063, Recent Winrate: 0.3870
# Episode: 364000, Lifetime winrate: 0.4064, Recent Winrate: 0.4350
# Episode: 365000, Lifetime winrate: 0.4064, Recent Winrate: 0.4080
# Episode: 366000, Lifetime winrate: 0.4063, Recent Winrate: 0.3910
# Episode: 367000, Lifetime winrate: 0.4064, Recent Winrate: 0.4260
# Episode: 368000, Lifetime winrate: 0.4064, Recent Winrate: 0.4180
# Episode: 369000, Lifetime winrate: 0.4064, Recent Winrate: 0.3910
# Episode: 370000, Lifetime winrate: 0.4064, Recent Winrate: 0.4050
# Episode: 371000, Lifetime winrate: 0.4063, Recent Winrate: 0.3870
# Episode: 372000, Lifetime winrate: 0.4063, Recent Winrate: 0.3940
# Episode: 373000, Lifetime winrate: 0.4064, Recent Winrate: 0.4280
# Episode: 374000, Lifetime winrate: 0.4064, Recent Winrate: 0.4330
# Episode: 375000, Lifetime winrate: 0.4065, Recent Winrate: 0.4210
# Episode: 376000, Lifetime winrate: 0.4064, Recent Winrate: 0.3980
# Episode: 377000, Lifetime winrate: 0.4064, Recent Winrate: 0.4010
# Episode: 378000, Lifetime winrate: 0.4064, Recent Winrate: 0.4060
# Episode: 379000, Lifetime winrate: 0.4065, Recent Winrate: 0.4170
# Episode: 380000, Lifetime winrate: 0.4066, Recent Winrate: 0.4500
# Episode: 381000, Lifetime winrate: 0.4066, Recent Winrate: 0.4080
# Episode: 382000, Lifetime winrate: 0.4066, Recent Winrate: 0.4160
# Episode: 383000, Lifetime winrate: 0.4066, Recent Winrate: 0.4120
# Episode: 384000, Lifetime winrate: 0.4066, Recent Winrate: 0.4070
# Episode: 385000, Lifetime winrate: 0.4066, Recent Winrate: 0.3980
# Episode: 386000, Lifetime winrate: 0.4067, Recent Winrate: 0.4440
# Episode: 387000, Lifetime winrate: 0.4067, Recent Winrate: 0.4110
# Episode: 388000, Lifetime winrate: 0.4067, Recent Winrate: 0.4220
# Episode: 389000, Lifetime winrate: 0.4067, Recent Winrate: 0.4100
# Episode: 390000, Lifetime winrate: 0.4068, Recent Winrate: 0.4100
# Episode: 391000, Lifetime winrate: 0.4068, Recent Winrate: 0.4210
# Episode: 392000, Lifetime winrate: 0.4068, Recent Winrate: 0.4130
# Episode: 393000, Lifetime winrate: 0.4068, Recent Winrate: 0.3990
# Episode: 394000, Lifetime winrate: 0.4068, Recent Winrate: 0.4030
# Episode: 395000, Lifetime winrate: 0.4067, Recent Winrate: 0.3900
# Episode: 396000, Lifetime winrate: 0.4067, Recent Winrate: 0.4090
# Episode: 397000, Lifetime winrate: 0.4067, Recent Winrate: 0.3870
# Episode: 398000, Lifetime winrate: 0.4068, Recent Winrate: 0.4500
# Episode: 399000, Lifetime winrate: 0.4068, Recent Winrate: 0.4130
# Episode: 400000, Lifetime winrate: 0.4068, Recent Winrate: 0.3930
# Episode: 401000, Lifetime winrate: 0.4068, Recent Winrate: 0.4080
# Episode: 402000, Lifetime winrate: 0.4068, Recent Winrate: 0.4220
# Episode: 403000, Lifetime winrate: 0.4069, Recent Winrate: 0.4230
# Episode: 404000, Lifetime winrate: 0.4068, Recent Winrate: 0.3910
# Episode: 405000, Lifetime winrate: 0.4068, Recent Winrate: 0.4120
# Episode: 406000, Lifetime winrate: 0.4069, Recent Winrate: 0.4320
# Episode: 407000, Lifetime winrate: 0.4070, Recent Winrate: 0.4430
# Episode: 408000, Lifetime winrate: 0.4070, Recent Winrate: 0.4160
# Episode: 409000, Lifetime winrate: 0.4070, Recent Winrate: 0.4060
# Episode: 410000, Lifetime winrate: 0.4070, Recent Winrate: 0.4200
# Episode: 411000, Lifetime winrate: 0.4071, Recent Winrate: 0.4280
# Episode: 412000, Lifetime winrate: 0.4072, Recent Winrate: 0.4350
# Episode: 413000, Lifetime winrate: 0.4072, Recent Winrate: 0.4200
# Episode: 414000, Lifetime winrate: 0.4072, Recent Winrate: 0.4020
# Episode: 415000, Lifetime winrate: 0.4072, Recent Winrate: 0.4200
# Episode: 416000, Lifetime winrate: 0.4072, Recent Winrate: 0.4000
# Episode: 417000, Lifetime winrate: 0.4072, Recent Winrate: 0.4320
# Episode: 418000, Lifetime winrate: 0.4073, Recent Winrate: 0.4230
# Episode: 419000, Lifetime winrate: 0.4073, Recent Winrate: 0.4020
# Episode: 420000, Lifetime winrate: 0.4073, Recent Winrate: 0.4270
# Episode: 421000, Lifetime winrate: 0.4073, Recent Winrate: 0.4060
# Episode: 422000, Lifetime winrate: 0.4073, Recent Winrate: 0.4010
# Episode: 423000, Lifetime winrate: 0.4073, Recent Winrate: 0.4280
# Episode: 424000, Lifetime winrate: 0.4074, Recent Winrate: 0.4180
# Episode: 425000, Lifetime winrate: 0.4074, Recent Winrate: 0.4210
# Episode: 426000, Lifetime winrate: 0.4074, Recent Winrate: 0.3960
# Episode: 427000, Lifetime winrate: 0.4074, Recent Winrate: 0.4310
# Episode: 428000, Lifetime winrate: 0.4075, Recent Winrate: 0.4260
# Episode: 429000, Lifetime winrate: 0.4076, Recent Winrate: 0.4480
# Episode: 430000, Lifetime winrate: 0.4075, Recent Winrate: 0.3910
# Episode: 431000, Lifetime winrate: 0.4075, Recent Winrate: 0.3960
# Episode: 432000, Lifetime winrate: 0.4076, Recent Winrate: 0.4490
# Episode: 433000, Lifetime winrate: 0.4077, Recent Winrate: 0.4370
# Episode: 434000, Lifetime winrate: 0.4076, Recent Winrate: 0.3860
# Episode: 435000, Lifetime winrate: 0.4076, Recent Winrate: 0.3950
# Episode: 436000, Lifetime winrate: 0.4076, Recent Winrate: 0.4240
# Episode: 437000, Lifetime winrate: 0.4075, Recent Winrate: 0.3720
# Episode: 438000, Lifetime winrate: 0.4076, Recent Winrate: 0.4250
# Episode: 439000, Lifetime winrate: 0.4076, Recent Winrate: 0.3930
# Episode: 440000, Lifetime winrate: 0.4076, Recent Winrate: 0.4310
# Episode: 441000, Lifetime winrate: 0.4076, Recent Winrate: 0.4110
# Episode: 442000, Lifetime winrate: 0.4076, Recent Winrate: 0.4030
# Episode: 443000, Lifetime winrate: 0.4076, Recent Winrate: 0.4210
# Episode: 444000, Lifetime winrate: 0.4076, Recent Winrate: 0.3830
# Episode: 445000, Lifetime winrate: 0.4076, Recent Winrate: 0.4140
# Episode: 446000, Lifetime winrate: 0.4077, Recent Winrate: 0.4340
# Episode: 447000, Lifetime winrate: 0.4076, Recent Winrate: 0.3950
# Episode: 448000, Lifetime winrate: 0.4076, Recent Winrate: 0.4120
# Episode: 449000, Lifetime winrate: 0.4077, Recent Winrate: 0.4220
# Episode: 450000, Lifetime winrate: 0.4077, Recent Winrate: 0.4160
# Episode: 451000, Lifetime winrate: 0.4077, Recent Winrate: 0.4220
# Episode: 452000, Lifetime winrate: 0.4077, Recent Winrate: 0.4140
# Episode: 453000, Lifetime winrate: 0.4078, Recent Winrate: 0.4290
# Episode: 454000, Lifetime winrate: 0.4078, Recent Winrate: 0.4190
# Episode: 455000, Lifetime winrate: 0.4078, Recent Winrate: 0.3980
# Episode: 456000, Lifetime winrate: 0.4078, Recent Winrate: 0.4330
# Episode: 457000, Lifetime winrate: 0.4078, Recent Winrate: 0.4090
# Episode: 458000, Lifetime winrate: 0.4078, Recent Winrate: 0.4130
# Episode: 459000, Lifetime winrate: 0.4079, Recent Winrate: 0.4100
# Episode: 460000, Lifetime winrate: 0.4078, Recent Winrate: 0.3810
# Episode: 461000, Lifetime winrate: 0.4079, Recent Winrate: 0.4420
# Episode: 462000, Lifetime winrate: 0.4079, Recent Winrate: 0.4390
# Episode: 463000, Lifetime winrate: 0.4079, Recent Winrate: 0.4080
# Episode: 464000, Lifetime winrate: 0.4080, Recent Winrate: 0.4140
# Episode: 465000, Lifetime winrate: 0.4080, Recent Winrate: 0.4140
# Episode: 466000, Lifetime winrate: 0.4080, Recent Winrate: 0.4230
# Episode: 467000, Lifetime winrate: 0.4080, Recent Winrate: 0.4210
# Episode: 468000, Lifetime winrate: 0.4080, Recent Winrate: 0.3880
# Episode: 469000, Lifetime winrate: 0.4080, Recent Winrate: 0.4090
# Episode: 470000, Lifetime winrate: 0.4080, Recent Winrate: 0.4080
# Episode: 471000, Lifetime winrate: 0.4081, Recent Winrate: 0.4420
# Episode: 472000, Lifetime winrate: 0.4080, Recent Winrate: 0.3980
# Episode: 473000, Lifetime winrate: 0.4080, Recent Winrate: 0.3910
# Episode: 474000, Lifetime winrate: 0.4080, Recent Winrate: 0.3910
# Episode: 475000, Lifetime winrate: 0.4079, Recent Winrate: 0.3890
# Episode: 476000, Lifetime winrate: 0.4079, Recent Winrate: 0.3850
# Episode: 477000, Lifetime winrate: 0.4079, Recent Winrate: 0.4260
# Episode: 478000, Lifetime winrate: 0.4079, Recent Winrate: 0.4200
# Episode: 479000, Lifetime winrate: 0.4080, Recent Winrate: 0.4280
# Episode: 480000, Lifetime winrate: 0.4080, Recent Winrate: 0.3980
# Episode: 481000, Lifetime winrate: 0.4080, Recent Winrate: 0.4150
# Episode: 482000, Lifetime winrate: 0.4080, Recent Winrate: 0.4040
# Episode: 483000, Lifetime winrate: 0.4080, Recent Winrate: 0.4380
# Episode: 484000, Lifetime winrate: 0.4080, Recent Winrate: 0.4190
# Episode: 485000, Lifetime winrate: 0.4081, Recent Winrate: 0.4160
# Episode: 486000, Lifetime winrate: 0.4081, Recent Winrate: 0.4140
# Episode: 487000, Lifetime winrate: 0.4081, Recent Winrate: 0.4120
# Episode: 488000, Lifetime winrate: 0.4081, Recent Winrate: 0.4230
# Episode: 489000, Lifetime winrate: 0.4082, Recent Winrate: 0.4390
# Episode: 490000, Lifetime winrate: 0.4082, Recent Winrate: 0.4010
# Episode: 491000, Lifetime winrate: 0.4082, Recent Winrate: 0.4310
# Episode: 492000, Lifetime winrate: 0.4082, Recent Winrate: 0.4150
# Episode: 493000, Lifetime winrate: 0.4083, Recent Winrate: 0.4250
# Episode: 494000, Lifetime winrate: 0.4083, Recent Winrate: 0.4080
# Episode: 495000, Lifetime winrate: 0.4083, Recent Winrate: 0.4120
# Episode: 496000, Lifetime winrate: 0.4083, Recent Winrate: 0.4200
# Episode: 497000, Lifetime winrate: 0.4084, Recent Winrate: 0.4410
# Episode: 498000, Lifetime winrate: 0.4084, Recent Winrate: 0.4530
# Episode: 499000, Lifetime winrate: 0.4085, Recent Winrate: 0.4560
# Episode: 500000, Lifetime winrate: 0.4085, Recent Winrate: 0.4100

# %%
torch.save(model.state_dict(), "bj_player_dense_big.pth")

# %%
model.load_state_dict(torch.load("bj_player_dense_big.pth", weights_only=True))
# Out:
# <All keys matched successfully>

# %%
model.eval()
wins = 0
num_games = 10_000
for _ in range(num_games):
    game = Game(five_card_charlie=True)
    # print("=============================")
    # print("Player hand:", *game.player_hand, "\nDealer hand:", *game.dealer_hand)
    while not game.is_over:
        state = get_game_state(game).to(device)
        output = model(state)
        # print(output)
        action = torch.argmax(output).item()
        if action == 0:
            # print("Bot hits")
            game.take_action("H")
        else:
            # print("Bot stays")
            game.take_action("S")
        # print("-----------------------------")
        # print("Player hand:", *game.player_hand, "\nDealer hand:", *game.dealer_hand)

    # print("Score:", game.score)
    wins += 1 if game.score == 1 else 0

print(f"Win rate: {100 * wins / num_games:.4f}%")
# Out:
# Win rate: 42.4600%
